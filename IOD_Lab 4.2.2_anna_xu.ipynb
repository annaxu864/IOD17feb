# %% [markdown]
# <div>
# <img src=https://www.institutedata.com/wp-content/uploads/2019/10/iod_h_tp_primary_c.svg width="300">
# </div>

# %% [markdown]
# ## Lab 4.2.2: Feature Selection

# %% [markdown]
# Moving beyond basic feature selection methods, this lab introduces forward feature selection. Through an iterative process, we progressively include features that contribute to improving the model's adjusted R-squared score. By systematically evaluating the impact of each feature, we aim to construct a regression model that captures the underlying patterns in the data.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %matplotlib inline

# %% [markdown]
# ### 5. Forward Feature Selection
#
# > Forward Selection: Forward selection is an iterative method in which we start with having no feature in the model. In each iteration, we keep adding the feature which best improves our model till an addition of a new variable does not improve the performance of the model.
#
# Create a Regression model using Forward Feature Selection by looping over all the features adding one at a time until there are no improvements on the prediction metric ( R2  and  AdjustedR2  in this case).

# %% [markdown]
# #### 5.1 Load Wine Data & Define Predictor and Target

# %%
## Load the wine quality dataset

# Load the wine dataset from csv
wine = pd.read_csv(r'C:\Users\lytton\Downloads\DATA\winequality_merged.csv')

# define the target variable (dependent variable) as y
y = wine['quality']

# Take all columns except target as predictor columns
predictor_columns = [c for c in wine.columns if c != 'quality']

# Load the dataset as a pandas data frame
X = pd.DataFrame(wine, columns = predictor_columns)

# %%
## Create training and testing subsets

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2)

# %% [markdown]
# #### 5.2 Overview of the code below
#
# The external `while` loop goes forever until there are no improvements to the model, which is controlled by the flag `changed` (until is **not** changed).
# The inner `for` loop goes over each of the features not yet included in the model and calculates the correlation coefficient. If any model improves on the previous best model then the records are updated.
#
# #### Code variables
# - `included`: list of the features (predictors) that were included in the model; starts empty.
# - `excluded`: list of features that have **not** been included in the model; starts as the full list of features.
# - `best`: dictionary to keep record of the best model found at any stage; starts 'empty'.
# - `model`: object of class LinearRegression, with default values for all parameters.
#
# #### Methods of the `LinearRegression` object to investigate
# - `fit()`
# - `fit.score()`
#
# #### Adjusted $R^2$ formula
# $$Adjusted \; R^2 = 1 - { (1 - R^2) (n - 1)  \over n - k - 1 }$$
#
# #### Linear Regression [reference](http://scikit-learn.org/stable/modules/generated/sklearn.linear_model.LinearRegression.html#sklearn.linear_model.LinearRegression)

# %%
show_steps = True   # for testing/debugging
# show_steps = False  # without showing steps

# %%
included = [] #Start with no features in the model.
best = {'feature': '', 'r2': 0, 'a_r2': 0} #Tracks the best feature found in the current round based on R^2 and adjusted R^2.
model = LinearRegression() #Creates a LR model and stores the no. of rows in training data.
n = X_train.shape[0] #Stores the no. of rows in training data.

while True:
    changed = False #A loop that keeps trying to add new features until no improvement is found. 

    if show_steps:
        print('') #Just a visual seperator, prints a blank line only if show_steps = True.

    excluded = list(set(X.columns) - set(included)) #Calculates which features haven’t been added to the model yet.

    if show_steps:
        print(f"(Step) Excluded = {', '.join(excluded)}") #Prints pool of remaining features to be tested.

    for new_column in excluded: #Loops through each unused feature.

        if show_steps:
            print(f'(Step) Trying {new_column}...') #Flags new variable it's testing.
            print(f"(Step) - Features = {', '.join(included + [new_column])}") #Flags new variable in conjunction with previous best variables.

        fit = model.fit(X_train[included + [new_column]], y_train) #Trains the model using current + one new feature,
        r2 = fit.score(X_train[included + [new_column]], y_train) #Calculates the R^2 score.
        k = len(included + [new_column]) #Number of predictors in this model.
        adjusted_r2 = 1 - ( ( (1 - r2) * (n - 1) ) / (n - k - 1) ) #Computes adjusted R^2, which corrects for model complexity (higher is better, but it can decrease if a feature doesn't add up).

        if show_steps:
            print(f"(Step) - Adjusted R^2: This = {adjusted_r2:.3f}; Best = {best['a_r2']:.3f}") #Prints adjusted R^2 with the new feature and best BEFORE testing the new feature to 3 decimal places. 

        if adjusted_r2 > best['a_r2']: #DECISION POINT: if the new feature improves adjusted R^2,
            best = {'feature': new_column, 'r2': r2, 'a_r2': adjusted_r2} #Record new parameters.
            changed = True  #Flag that a better model is found.
            if show_steps:
                print(f"(Step) - New Best!   : Feature = {best['feature']}; R^2 = {best['r2']:.3f}; Adjusted R^2 = {best['a_r2']:.3f}")

    if changed: #If a better model is found after testing all remaining features,
        included.append(best['feature']) #Append new best feature to included list.
        excluded = list(set(excluded) - set(best['feature'])) #Update excluded list.
        print(f"Added feature {best['feature']} with R^2 = {best['r2']:.3f} and adjusted R^2 = {best['a_r2']:.3f}")

    else:
        print('*'*50) #Just a visual seperator, it prints 50 asterisks.
        break

print('')
print('Resulting features:')
print(', '.join(included))
# Out:
# (Step) Excluded = total sulfur dioxide, red_wine, density, alcohol, citric acid, sulphates, chlorides, volatile acidity, pH, free sulfur dioxide, residual sugar, fixed acidity
# (Step) Trying total sulfur dioxide...
# (Step) - Features = total sulfur dioxide
# (Step) - Adjusted R^2: This = 0.002; Best = 0.000
# (Step) - New Best!   : Feature = total sulfur dioxide; R^2 = 0.002; Adjusted R^2 = 0.002
# (Step) Trying red_wine...
# (Step) - Features = red_wine
# (Step) - Adjusted R^2: This = 0.014; Best = 0.002
# (Step) - New Best!   : Feature = red_wine; R^2 = 0.014; Adjusted R^2 = 0.014
# (Step) Trying density...
# (Step) - Features = density
# (Step) - Adjusted R^2: This = 0.093; Best = 0.014
# (Step) - New Best!   : Feature = density; R^2 = 0.093; Adjusted R^2 = 0.093
# (Step) Trying alcohol...
# (Step) - Features = alcohol
# (Step) - Adjusted R^2: This = 0.198; Best = 0.093
# (Step) - New Best!   : Feature = alcohol; R^2 = 0.198; Adjusted R^2 = 0.198
# (Step) Trying citric acid...
# (Step) - Features = citric acid
# (Step) - Adjusted R^2: This = 0.008; Best = 0.198
# (Step) Trying sulphates...
# (Step) - Features = sulphates
# (Step) - Adjusted R^2: This = 0.001; Best = 0.198
# (Step) Trying chlorides...
# (Step) - Features = chlorides
# (Step) - Adjusted R^2: This = 0.043; Best = 0.198
# (Step) Trying volatile acidity...
# (Step) - Features = volatile acidity
# (Step) - Adjusted R^2: This = 0.071; Best = 0.198
# (Step) Trying pH...
# (Step) - Features = pH
# (Step) - Adjusted R^2: This = 0.000; Best = 0.198
# (Step) Trying free sulfur dioxide...
# (Step) - Features = free sulfur dioxide
# (Step) - Adjusted R^2: This = 0.001; Best = 0.198
# (Step) Trying residual sugar...
# (Step) - Features = residual sugar
# (Step) - Adjusted R^2: This = 0.001; Best = 0.198
# (Step) Trying fixed acidity...
# (Step) - Features = fixed acidity
# (Step) - Adjusted R^2: This = 0.005; Best = 0.198
# Added feature alcohol with R^2 = 0.198 and adjusted R^2 = 0.198
#
# (Step) Excluded = total sulfur dioxide, red_wine, density, citric acid, sulphates, chlorides, volatile acidity, pH, free sulfur dioxide, residual sugar, fixed acidity
# (Step) Trying total sulfur dioxide...
# (Step) - Features = alcohol, total sulfur dioxide
# (Step) - Adjusted R^2: This = 0.202; Best = 0.198
# (Step) - New Best!   : Feature = total sulfur dioxide; R^2 = 0.203; Adjusted R^2 = 0.202
# (Step) Trying red_wine...
# (Step) - Features = alcohol, red_wine
# (Step) - Adjusted R^2: This = 0.208; Best = 0.202
# (Step) - New Best!   : Feature = red_wine; R^2 = 0.208; Adjusted R^2 = 0.208
# (Step) Trying density...
# (Step) - Features = alcohol, density
# (Step) - Adjusted R^2: This = 0.198; Best = 0.208
# (Step) Trying citric acid...
# (Step) - Features = alcohol, citric acid
# (Step) - Adjusted R^2: This = 0.207; Best = 0.208
# (Step) Trying sulphates...
# (Step) - Features = alcohol, sulphates
# (Step) - Adjusted R^2: This = 0.199; Best = 0.208
# (Step) Trying chlorides...
# (Step) - Features = alcohol, chlorides
# (Step) - Adjusted R^2: This = 0.206; Best = 0.208
# (Step) Trying volatile acidity...
# (Step) - Features = alcohol, volatile acidity
# (Step) - Adjusted R^2: This = 0.260; Best = 0.208
# (Step) - New Best!   : Feature = volatile acidity; R^2 = 0.260; Adjusted R^2 = 0.260
# (Step) Trying pH...
# (Step) - Features = alcohol, pH
# (Step) - Adjusted R^2: This = 0.199; Best = 0.260
# (Step) Trying free sulfur dioxide...
# (Step) - Features = alcohol, free sulfur dioxide
# (Step) - Adjusted R^2: This = 0.212; Best = 0.260
# (Step) Trying residual sugar...
# (Step) - Features = alcohol, residual sugar
# (Step) - Adjusted R^2: This = 0.213; Best = 0.260
# (Step) Trying fixed acidity...
# (Step) - Features = alcohol, fixed acidity
# (Step) - Adjusted R^2: This = 0.199; Best = 0.260
# Added feature volatile acidity with R^2 = 0.260 and adjusted R^2 = 0.260
#
# (Step) Excluded = total sulfur dioxide, red_wine, density, citric acid, sulphates, chlorides, pH, free sulfur dioxide, residual sugar, fixed acidity
# (Step) Trying total sulfur dioxide...
# (Step) - Features = alcohol, volatile acidity, total sulfur dioxide
# (Step) - Adjusted R^2: This = 0.262; Best = 0.260
# (Step) - New Best!   : Feature = total sulfur dioxide; R^2 = 0.262; Adjusted R^2 = 0.262
# (Step) Trying red_wine...
# (Step) - Features = alcohol, volatile acidity, red_wine
# (Step) - Adjusted R^2: This = 0.266; Best = 0.262
# (Step) - New Best!   : Feature = red_wine; R^2 = 0.266; Adjusted R^2 = 0.266
# (Step) Trying density...
# (Step) - Features = alcohol, volatile acidity, density
# (Step) - Adjusted R^2: This = 0.267; Best = 0.266
# (Step) - New Best!   : Feature = density; R^2 = 0.268; Adjusted R^2 = 0.267
# (Step) Trying citric acid...
# (Step) - Features = alcohol, volatile acidity, citric acid
# (Step) - Adjusted R^2: This = 0.259; Best = 0.267
# (Step) Trying sulphates...
# (Step) - Features = alcohol, volatile acidity, sulphates
# (Step) - Adjusted R^2: This = 0.269; Best = 0.267
# (Step) - New Best!   : Feature = sulphates; R^2 = 0.269; Adjusted R^2 = 0.269
# (Step) Trying chlorides...
# (Step) - Features = alcohol, volatile acidity, chlorides
# (Step) - Adjusted R^2: This = 0.259; Best = 0.269
# (Step) Trying pH...
# (Step) - Features = alcohol, volatile acidity, pH
# (Step) - Adjusted R^2: This = 0.261; Best = 0.269
# (Step) Trying free sulfur dioxide...
# (Step) - Features = alcohol, volatile acidity, free sulfur dioxide
# (Step) - Adjusted R^2: This = 0.260; Best = 0.269
# (Step) Trying residual sugar...
# (Step) - Features = alcohol, volatile acidity, residual sugar
# (Step) - Adjusted R^2: This = 0.264; Best = 0.269
# (Step) Trying fixed acidity...
# (Step) - Features = alcohol, volatile acidity, fixed acidity
# (Step) - Adjusted R^2: This = 0.260; Best = 0.269
# Added feature sulphates with R^2 = 0.269 and adjusted R^2 = 0.269
#
# (Step) Excluded = free sulfur dioxide, fixed acidity, density, residual sugar, citric acid, chlorides, pH, red_wine, total sulfur dioxide
# (Step) Trying free sulfur dioxide...
# (Step) - Features = alcohol, volatile acidity, sulphates, free sulfur dioxide
# (Step) - Adjusted R^2: This = 0.271; Best = 0.269
# (Step) - New Best!   : Feature = free sulfur dioxide; R^2 = 0.271; Adjusted R^2 = 0.271
# (Step) Trying fixed acidity...
# (Step) - Features = alcohol, volatile acidity, sulphates, fixed acidity
# (Step) - Adjusted R^2: This = 0.269; Best = 0.271
# (Step) Trying density...
# (Step) - Features = alcohol, volatile acidity, sulphates, density
# (Step) - Adjusted R^2: This = 0.272; Best = 0.271
# (Step) - New Best!   : Feature = density; R^2 = 0.273; Adjusted R^2 = 0.272
# (Step) Trying residual sugar...
# (Step) - Features = alcohol, volatile acidity, sulphates, residual sugar
# (Step) - Adjusted R^2: This = 0.276; Best = 0.272
# (Step) - New Best!   : Feature = residual sugar; R^2 = 0.277; Adjusted R^2 = 0.276
# (Step) Trying citric acid...
# (Step) - Features = alcohol, volatile acidity, sulphates, citric acid
# (Step) - Adjusted R^2: This = 0.269; Best = 0.276
# (Step) Trying chlorides...
# (Step) - Features = alcohol, volatile acidity, sulphates, chlorides
# (Step) - Adjusted R^2: This = 0.270; Best = 0.276
# (Step) Trying pH...
# (Step) - Features = alcohol, volatile acidity, sulphates, pH
# (Step) - Adjusted R^2: This = 0.269; Best = 0.276
# (Step) Trying red_wine...
# (Step) - Features = alcohol, volatile acidity, sulphates, red_wine
# (Step) - Adjusted R^2: This = 0.270; Best = 0.276
# (Step) Trying total sulfur dioxide...
# (Step) - Features = alcohol, volatile acidity, sulphates, total sulfur dioxide
# (Step) - Adjusted R^2: This = 0.269; Best = 0.276
# Added feature residual sugar with R^2 = 0.277 and adjusted R^2 = 0.276
#
# (Step) Excluded = free sulfur dioxide, fixed acidity, density, citric acid, chlorides, pH, red_wine, total sulfur dioxide
# (Step) Trying free sulfur dioxide...
# (Step) - Features = alcohol, volatile acidity, sulphates, residual sugar, free sulfur dioxide
# (Step) - Adjusted R^2: This = 0.276; Best = 0.276
# (Step) - New Best!   : Feature = free sulfur dioxide; R^2 = 0.277; Adjusted R^2 = 0.276
# (Step) Trying fixed acidity...
# (Step) - Features = alcohol, volatile acidity, sulphates, residual sugar, fixed acidity
# (Step) - Adjusted R^2: This = 0.276; Best = 0.276
# (Step) Trying density...
# (Step) - Features = alcohol, volatile acidity, sulphates, residual sugar, density
# (Step) - Adjusted R^2: This = 0.276; Best = 0.276
# (Step) Trying citric acid...
# (Step) - Features = alcohol, volatile acidity, sulphates, residual sugar, citric acid
# (Step) - Adjusted R^2: This = 0.277; Best = 0.276
# (Step) - New Best!   : Feature = citric acid; R^2 = 0.277; Adjusted R^2 = 0.277
# (Step) Trying chlorides...
# (Step) - Features = alcohol, volatile acidity, sulphates, residual sugar, chlorides
# (Step) - Adjusted R^2: This = 0.276; Best = 0.277
# (Step) Trying pH...
# (Step) - Features = alcohol, volatile acidity, sulphates, residual sugar, pH
# (Step) - Adjusted R^2: This = 0.278; Best = 0.277
# (Step) - New Best!   : Feature = pH; R^2 = 0.278; Adjusted R^2 = 0.278
# (Step) Trying red_wine...
# (Step) - Features = alcohol, volatile acidity, sulphates, residual sugar, red_wine
# (Step) - Adjusted R^2: This = 0.281; Best = 0.278
# (Step) - New Best!   : Feature = red_wine; R^2 = 0.281; Adjusted R^2 = 0.281
# (Step) Trying total sulfur dioxide...
# (Step) - Features = alcohol, volatile acidity, sulphates, residual sugar, total sulfur dioxide
# (Step) - Adjusted R^2: This = 0.280; Best = 0.281
# Added feature red_wine with R^2 = 0.281 and adjusted R^2 = 0.281
#
# (Step) Excluded = free sulfur dioxide, density, citric acid, chlorides, pH, fixed acidity, total sulfur dioxide
# (Step) Trying free sulfur dioxide...
# (Step) - Features = alcohol, volatile acidity, sulphates, residual sugar, red_wine, free sulfur dioxide
# (Step) - Adjusted R^2: This = 0.282; Best = 0.281
# (Step) - New Best!   : Feature = free sulfur dioxide; R^2 = 0.283; Adjusted R^2 = 0.282
# (Step) Trying density...
# (Step) - Features = alcohol, volatile acidity, sulphates, residual sugar, red_wine, density
# (Step) - Adjusted R^2: This = 0.284; Best = 0.282
# (Step) - New Best!   : Feature = density; R^2 = 0.285; Adjusted R^2 = 0.284
# (Step) Trying citric acid...
# (Step) - Features = alcohol, volatile acidity, sulphates, residual sugar, red_wine, citric acid
# (Step) - Adjusted R^2: This = 0.281; Best = 0.284
# (Step) Trying chlorides...
# (Step) - Features = alcohol, volatile acidity, sulphates, residual sugar, red_wine, chlorides
# (Step) - Adjusted R^2: This = 0.282; Best = 0.284
# (Step) Trying pH...
# (Step) - Features = alcohol, volatile acidity, sulphates, residual sugar, red_wine, pH
# (Step) - Adjusted R^2: This = 0.282; Best = 0.284
# (Step) Trying fixed acidity...
# (Step) - Features = alcohol, volatile acidity, sulphates, residual sugar, red_wine, fixed acidity
# (Step) - Adjusted R^2: This = 0.281; Best = 0.284
# (Step) Trying total sulfur dioxide...
# (Step) - Features = alcohol, volatile acidity, sulphates, residual sugar, red_wine, total sulfur dioxide
# (Step) - Adjusted R^2: This = 0.281; Best = 0.284
# Added feature density with R^2 = 0.285 and adjusted R^2 = 0.284
#
# (Step) Excluded = total sulfur dioxide, citric acid, chlorides, pH, fixed acidity, free sulfur dioxide
# (Step) Trying total sulfur dioxide...
# (Step) - Features = alcohol, volatile acidity, sulphates, residual sugar, red_wine, density, total sulfur dioxide
# (Step) - Adjusted R^2: This = 0.284; Best = 0.284
# (Step) - New Best!   : Feature = total sulfur dioxide; R^2 = 0.285; Adjusted R^2 = 0.284
# (Step) Trying citric acid...
# (Step) - Features = alcohol, volatile acidity, sulphates, residual sugar, red_wine, density, citric acid
# (Step) - Adjusted R^2: This = 0.284; Best = 0.284
# (Step) Trying chlorides...
# (Step) - Features = alcohol, volatile acidity, sulphates, residual sugar, red_wine, density, chlorides
# (Step) - Adjusted R^2: This = 0.285; Best = 0.284
# (Step) - New Best!   : Feature = chlorides; R^2 = 0.286; Adjusted R^2 = 0.285
# (Step) Trying pH...
# (Step) - Features = alcohol, volatile acidity, sulphates, residual sugar, red_wine, density, pH
# (Step) - Adjusted R^2: This = 0.285; Best = 0.285
# (Step) Trying fixed acidity...
# (Step) - Features = alcohol, volatile acidity, sulphates, residual sugar, red_wine, density, fixed acidity
# (Step) - Adjusted R^2: This = 0.284; Best = 0.285
# (Step) Trying free sulfur dioxide...
# (Step) - Features = alcohol, volatile acidity, sulphates, residual sugar, red_wine, density, free sulfur dioxide
# (Step) - Adjusted R^2: This = 0.285; Best = 0.285
# Added feature chlorides with R^2 = 0.286 and adjusted R^2 = 0.285
#
# (Step) Excluded = total sulfur dioxide, citric acid, pH, fixed acidity, free sulfur dioxide
# (Step) Trying total sulfur dioxide...
# (Step) - Features = alcohol, volatile acidity, sulphates, residual sugar, red_wine, density, chlorides, total sulfur dioxide
# (Step) - Adjusted R^2: This = 0.286; Best = 0.285
# (Step) - New Best!   : Feature = total sulfur dioxide; R^2 = 0.287; Adjusted R^2 = 0.286
# (Step) Trying citric acid...
# (Step) - Features = alcohol, volatile acidity, sulphates, residual sugar, red_wine, density, chlorides, citric acid
# (Step) - Adjusted R^2: This = 0.285; Best = 0.286
# (Step) Trying pH...
# (Step) - Features = alcohol, volatile acidity, sulphates, residual sugar, red_wine, density, chlorides, pH
# (Step) - Adjusted R^2: This = 0.286; Best = 0.286
# (Step) - New Best!   : Feature = pH; R^2 = 0.287; Adjusted R^2 = 0.286
# (Step) Trying fixed acidity...
# (Step) - Features = alcohol, volatile acidity, sulphates, residual sugar, red_wine, density, chlorides, fixed acidity
# (Step) - Adjusted R^2: This = 0.285; Best = 0.286
# (Step) Trying free sulfur dioxide...
# (Step) - Features = alcohol, volatile acidity, sulphates, residual sugar, red_wine, density, chlorides, free sulfur dioxide
# (Step) - Adjusted R^2: This = 0.286; Best = 0.286
# (Step) - New Best!   : Feature = free sulfur dioxide; R^2 = 0.287; Adjusted R^2 = 0.286
# Added feature free sulfur dioxide with R^2 = 0.287 and adjusted R^2 = 0.286
#
# (Step) Excluded = pH, citric acid, fixed acidity, total sulfur dioxide
# (Step) Trying pH...
# (Step) - Features = alcohol, volatile acidity, sulphates, residual sugar, red_wine, density, chlorides, free sulfur dioxide, pH
# (Step) - Adjusted R^2: This = 0.287; Best = 0.286
# (Step) - New Best!   : Feature = pH; R^2 = 0.288; Adjusted R^2 = 0.287
# (Step) Trying citric acid...
# (Step) - Features = alcohol, volatile acidity, sulphates, residual sugar, red_wine, density, chlorides, free sulfur dioxide, citric acid
# (Step) - Adjusted R^2: This = 0.286; Best = 0.287
# (Step) Trying fixed acidity...
# (Step) - Features = alcohol, volatile acidity, sulphates, residual sugar, red_wine, density, chlorides, free sulfur dioxide, fixed acidity
# (Step) - Adjusted R^2: This = 0.286; Best = 0.287
# (Step) Trying total sulfur dioxide...
# (Step) - Features = alcohol, volatile acidity, sulphates, residual sugar, red_wine, density, chlorides, free sulfur dioxide, total sulfur dioxide
# (Step) - Adjusted R^2: This = 0.289; Best = 0.287
# (Step) - New Best!   : Feature = total sulfur dioxide; R^2 = 0.290; Adjusted R^2 = 0.289
# Added feature total sulfur dioxide with R^2 = 0.290 and adjusted R^2 = 0.289
#
# (Step) Excluded = pH, fixed acidity, citric acid
# (Step) Trying pH...
# (Step) - Features = alcohol, volatile acidity, sulphates, residual sugar, red_wine, density, chlorides, free sulfur dioxide, total sulfur dioxide, pH
# (Step) - Adjusted R^2: This = 0.290; Best = 0.289
# (Step) - New Best!   : Feature = pH; R^2 = 0.291; Adjusted R^2 = 0.290
# (Step) Trying fixed acidity...
# (Step) - Features = alcohol, volatile acidity, sulphates, residual sugar, red_wine, density, chlorides, free sulfur dioxide, total sulfur dioxide, fixed acidity
# (Step) - Adjusted R^2: This = 0.289; Best = 0.290
# (Step) Trying citric acid...
# (Step) - Features = alcohol, volatile acidity, sulphates, residual sugar, red_wine, density, chlorides, free sulfur dioxide, total sulfur dioxide, citric acid
# (Step) - Adjusted R^2: This = 0.289; Best = 0.290
# Added feature pH with R^2 = 0.291 and adjusted R^2 = 0.290
#
# (Step) Excluded = fixed acidity, citric acid
# (Step) Trying fixed acidity...
# (Step) - Features = alcohol, volatile acidity, sulphates, residual sugar, red_wine, density, chlorides, free sulfur dioxide, total sulfur dioxide, pH, fixed acidity
# (Step) - Adjusted R^2: This = 0.292; Best = 0.290
# (Step) - New Best!   : Feature = fixed acidity; R^2 = 0.294; Adjusted R^2 = 0.292
# (Step) Trying citric acid...
# (Step) - Features = alcohol, volatile acidity, sulphates, residual sugar, red_wine, density, chlorides, free sulfur dioxide, total sulfur dioxide, pH, citric acid
# (Step) - Adjusted R^2: This = 0.290; Best = 0.292
# Added feature fixed acidity with R^2 = 0.294 and adjusted R^2 = 0.292
#
# (Step) Excluded = citric acid
# (Step) Trying citric acid...
# (Step) - Features = alcohol, volatile acidity, sulphates, residual sugar, red_wine, density, chlorides, free sulfur dioxide, total sulfur dioxide, pH, fixed acidity, citric acid
# (Step) - Adjusted R^2: This = 0.292; Best = 0.292
# **************************************************
#
# Resulting features:
# alcohol, volatile acidity, sulphates, residual sugar, red_wine, density, chlorides, free sulfur dioxide, total sulfur dioxide, pH, fixed acidity

# %%
#Data Scientist not expected to be able to write this code from scratch.
#Documentation for repeatability and storytelling/communication to the business is key for Data Scientists now.

# %% [markdown]
# ---
#
#
#
# ---
#
#
#
# > > > > > > > > > © 2024 Institute of Data
#
#
# ---
#
#
#
# ---
